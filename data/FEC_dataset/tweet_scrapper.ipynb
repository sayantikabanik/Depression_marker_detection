# %%
# !pip install snscrape

# %%
import snscrape.modules.twitter as sntwitter
import pandas as pd

# Creating list to append tweet data to
tweets_list2 = []

# Using TwitterSearchScraper to scrape data and append tweets to list
for i,tweet in enumerate(sntwitter.TwitterSearchScraper('Depression since:2022-03-01 until:2022-03-19').get_items()):
    if i>500000:
        break
    tweets_list2.append([tweet.date, tweet.id, tweet.content])
    
# Creating a dataframe from the tweets list above
tweets_df2 = pd.DataFrame(tweets_list2, columns=['Datetime', 'Tweet Id', 'Text'])

# %%
tweets_df2
# Out:
#                         Datetime             Tweet Id  \
# 0      2022-03-18 23:59:58+00:00  1504970902253015048
# 1      2022-03-18 23:59:51+00:00  1504970870867075073
# 2      2022-03-18 23:59:51+00:00  1504970870275588098
# 3      2022-03-18 23:59:47+00:00  1504970853523632137
# 4      2022-03-18 23:59:42+00:00  1504970835941109763
# ...                          ...                  ...
# 299944 2022-03-01 00:00:15+00:00  1498447989601456128
# 299945 2022-03-01 00:00:15+00:00  1498447989098041351
# 299946 2022-03-01 00:00:08+00:00  1498447962028060681
# 299947 2022-03-01 00:00:06+00:00  1498447954876715012
# 299948 2022-03-01 00:00:00+00:00  1498447928414846981
#
#                                                      Text
# 0       @itsjustmarsha Same. same. Separation Anxiety ...
# 1       @cherry_charline bah ça c’est moi, j’étais en ...
# 2       why does no one talk about how depression and ...
# 3       @CrimsonDullahan I know, but its the vibe with...
# ...

# %%
tweets_df2.to_csv('Depression_tweets3.csv')
